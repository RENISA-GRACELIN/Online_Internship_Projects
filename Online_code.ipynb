# %% [markdown]
# <a href="https://colab.research.google.com/github/RENISA-GRACELIN/Online_Internship_Projects/blob/main/Online_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time
import torch
from torch.utils.data import DataLoader
from torchvision import transforms, models, datasets

# Define the path to your dataset
train_data_dir = '/content/drive/MyDrive/DR_50/Train'
test_data_dir = '/content/drive/MyDrive/DR_50/Test'

# Define transforms for data augmentation and normalization
tform = transforms.Compose([
    transforms.RandomRotation(20),
    transforms.Resize((224, 224)),  # Resize to match input size of ResNet18
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # ImageNet normalization
])

# Load the datasets
train_dataset = datasets.ImageFolder(root=train_data_dir, transform=tform)
test_dataset = datasets.ImageFolder(root=test_data_dir, transform=tform)

# Define the batch size
batch_size = 32

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Use a pre-trained ResNet18
model = models.resnet18(pretrained=True)

# Convert model to grayscale
model.conv1 = torch.nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3, bias=False)

# Update the fully connected layer based on the number of classes in the dataset
model.fc = torch.nn.Linear(model.fc.in_features, len(train_dataset.classes))

model.to(device)

# Specify the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# Define the training function
def train_one_epoch(model, optimizer, data_loader, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    for i, (inputs, labels) in enumerate(data_loader):
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    accuracy = 100 * correct / total
    print('Training Loss: {:.4f}, Accuracy: {:.2f}%'.format(running_loss / len(data_loader), accuracy))

# Define the testing function
def test_model(model, data_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
    accuracy = 100 * correct / total
    print('Testing Accuracy: {:.2f}%'.format(accuracy))

# Train and test the model
num_epochs = 100
for epoch in range(num_epochs):
    print('Epoch {}/{}'.format(epoch+1, num_epochs))
    print('-' * 10)
    train_one_epoch(model, optimizer, train_loader, device)
    test_model(model, test_loader)

print('Finished Training')
# Out:
# Epoch 1/100
# ----------
# Training Loss: 1.6794, Accuracy: 21.14%
# Testing Accuracy: 28.00%
# Epoch 2/100
# ----------
# Training Loss: 1.4056, Accuracy: 43.43%
# Testing Accuracy: 20.00%
# Epoch 3/100
# ----------
# Training Loss: 1.2013, Accuracy: 58.86%
# Testing Accuracy: 28.00%
# Epoch 4/100
# ----------
# Training Loss: 0.9625, Accuracy: 70.29%
# Testing Accuracy: 28.00%
# Epoch 5/100
# ----------
# Training Loss: 0.8517, Accuracy: 72.57%
# Testing Accuracy: 36.00%
# Epoch 6/100
# ----------
# Training Loss: 0.7235, Accuracy: 80.00%
# Testing Accuracy: 40.00%
# Epoch 7/100
# ----------
# Training Loss: 0.6598, Accuracy: 81.14%
# Testing Accuracy: 40.00%
# Epoch 8/100
# ----------
# Training Loss: 0.5479, Accuracy: 85.14%
# Testing Accuracy: 64.00%
# Epoch 9/100
# ----------
# Training Loss: 0.4648, Accuracy: 88.00%
# Testing Accuracy: 40.00%
# Epoch 10/100
# ----------
# Training Loss: 0.3857, Accuracy: 93.14%
# Testing Accuracy: 48.00%
# Epoch 11/100
# ----------
# Training Loss: 0.3615, Accuracy: 93.71%
# Testing Accuracy: 44.00%
# Epoch 12/100
# ----------
# Training Loss: 0.3155, Accuracy: 94.29%
# Testing Accuracy: 48.00%
# Epoch 13/100
# ----------
# Training Loss: 0.2847, Accuracy: 94.29%
# Testing Accuracy: 48.00%
# Epoch 14/100
# ----------
# Training Loss: 0.2941, Accuracy: 94.86%
# Testing Accuracy: 48.00%
# Epoch 15/100
# ----------
# Training Loss: 0.2226, Accuracy: 95.43%
# Testing Accuracy: 56.00%
# Epoch 16/100
# ----------
# Training Loss: 0.2301, Accuracy: 97.14%
# Testing Accuracy: 40.00%
# Epoch 17/100
# ----------
# Training Loss: 0.2001, Accuracy: 97.14%
# Testing Accuracy: 52.00%
# Epoch 18/100
# ----------
# Training Loss: 0.1945, Accuracy: 98.86%
# Testing Accuracy: 44.00%
# Epoch 19/100
# ----------
# Training Loss: 0.1738, Accuracy: 97.71%
# Testing Accuracy: 44.00%
# Epoch 20/100
# ----------
# Training Loss: 0.1183, Accuracy: 98.86%
# Testing Accuracy: 52.00%
# Epoch 21/100
# ----------
# Training Loss: 0.1173, Accuracy: 98.86%
# Testing Accuracy: 56.00%
# Epoch 22/100
# ----------
# Training Loss: 0.1469, Accuracy: 97.71%
# Testing Accuracy: 52.00%
# Epoch 23/100
# ----------
# Training Loss: 0.0745, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 24/100
# ----------
# Training Loss: 0.0863, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 25/100
# ----------
# Training Loss: 0.0630, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 26/100
# ----------
# Training Loss: 0.0739, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 27/100
# ----------
# Training Loss: 0.0784, Accuracy: 97.71%
# Testing Accuracy: 48.00%
# Epoch 28/100
# ----------
# Training Loss: 0.0488, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 29/100
# ----------
# Training Loss: 0.0582, Accuracy: 99.43%
# Testing Accuracy: 44.00%
# Epoch 30/100
# ----------
# Training Loss: 0.0660, Accuracy: 99.43%
# Testing Accuracy: 56.00%
# Epoch 31/100
# ----------
# Training Loss: 0.0472, Accuracy: 99.43%
# Testing Accuracy: 60.00%
# Epoch 32/100
# ----------
# Training Loss: 0.1303, Accuracy: 97.14%
# Testing Accuracy: 44.00%
# Epoch 33/100
# ----------
# Training Loss: 0.1060, Accuracy: 97.71%
# Testing Accuracy: 44.00%
# Epoch 34/100
# ----------
# Training Loss: 0.0463, Accuracy: 100.00%
# Testing Accuracy: 32.00%
# Epoch 35/100
# ----------
# Training Loss: 0.0753, Accuracy: 99.43%
# Testing Accuracy: 52.00%
# Epoch 36/100
# ----------
# Training Loss: 0.0439, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 37/100
# ----------
# Training Loss: 0.0487, Accuracy: 99.43%
# Testing Accuracy: 56.00%
# Epoch 38/100
# ----------
# Training Loss: 0.0395, Accuracy: 100.00%
# Testing Accuracy: 48.00%
# Epoch 39/100
# ----------
# Training Loss: 0.0386, Accuracy: 99.43%
# Testing Accuracy: 44.00%
# Epoch 40/100
# ----------
# Training Loss: 0.0251, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 41/100
# ----------
# Training Loss: 0.0355, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 42/100
# ----------
# Training Loss: 0.0338, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 43/100
# ----------
# Training Loss: 0.0601, Accuracy: 99.43%
# Testing Accuracy: 48.00%
# Epoch 44/100
# ----------
# Training Loss: 0.0276, Accuracy: 100.00%
# Testing Accuracy: 48.00%
# Epoch 45/100
# ----------
# Training Loss: 0.0393, Accuracy: 99.43%
# Testing Accuracy: 56.00%
# Epoch 46/100
# ----------
# Training Loss: 0.0449, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 47/100
# ----------
# Training Loss: 0.0443, Accuracy: 99.43%
# Testing Accuracy: 52.00%
# Epoch 48/100
# ----------
# Training Loss: 0.0174, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 49/100
# ----------
# Training Loss: 0.0254, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 50/100
# ----------
# Training Loss: 0.0256, Accuracy: 100.00%
# Testing Accuracy: 44.00%
# Epoch 51/100
# ----------
# Training Loss: 0.0216, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 52/100
# ----------
# Training Loss: 0.0256, Accuracy: 100.00%
# Testing Accuracy: 68.00%
# Epoch 53/100
# ----------
# Training Loss: 0.0279, Accuracy: 100.00%
# Testing Accuracy: 68.00%
# Epoch 54/100
# ----------
# Training Loss: 0.0108, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 55/100
# ----------
# Training Loss: 0.0228, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 56/100
# ----------
# Training Loss: 0.0368, Accuracy: 99.43%
# Testing Accuracy: 60.00%
# Epoch 57/100
# ----------
# Training Loss: 0.0213, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 58/100
# ----------
# Training Loss: 0.0231, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 59/100
# ----------
# Training Loss: 0.0545, Accuracy: 98.29%
# Testing Accuracy: 60.00%
# Epoch 60/100
# ----------
# Training Loss: 0.0339, Accuracy: 100.00%
# Testing Accuracy: 44.00%
# Epoch 61/100
# ----------
# Training Loss: 0.0237, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 62/100
# ----------
# Training Loss: 0.0168, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 63/100
# ----------
# Training Loss: 0.0158, Accuracy: 100.00%
# Testing Accuracy: 48.00%
# Epoch 64/100
# ----------
# Training Loss: 0.0390, Accuracy: 99.43%
# Testing Accuracy: 56.00%
# Epoch 65/100
# ----------
# Training Loss: 0.0180, Accuracy: 100.00%
# Testing Accuracy: 44.00%
# Epoch 66/100
# ----------
# Training Loss: 0.0189, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 67/100
# ----------
# Training Loss: 0.0151, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 68/100
# ----------
# Training Loss: 0.0216, Accuracy: 99.43%
# Testing Accuracy: 56.00%
# Epoch 69/100
# ----------
# Training Loss: 0.0535, Accuracy: 99.43%
# Testing Accuracy: 52.00%
# Epoch 70/100
# ----------
# Training Loss: 0.0100, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 71/100
# ----------
# Training Loss: 0.0171, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 72/100
# ----------
# Training Loss: 0.0135, Accuracy: 100.00%
# Testing Accuracy: 52.00%
# Epoch 73/100
# ----------
# Training Loss: 0.0092, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 74/100
# ----------
# Training Loss: 0.0121, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 75/100
# ----------
# Training Loss: 0.0092, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 76/100
# ----------
# Training Loss: 0.0109, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 77/100
# ----------
# Training Loss: 0.0078, Accuracy: 100.00%
# Testing Accuracy: 68.00%
# Epoch 78/100
# ----------
# Training Loss: 0.0078, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 79/100
# ----------
# Training Loss: 0.0196, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 80/100
# ----------
# Training Loss: 0.0106, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 81/100
# ----------
# Training Loss: 0.0076, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 82/100
# ----------
# Training Loss: 0.0250, Accuracy: 99.43%
# Testing Accuracy: 68.00%
# Epoch 83/100
# ----------
# Training Loss: 0.0085, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 84/100
# ----------
# Training Loss: 0.0134, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 85/100
# ----------
# Training Loss: 0.0131, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 86/100
# ----------
# Training Loss: 0.0205, Accuracy: 100.00%
# Testing Accuracy: 68.00%
# Epoch 87/100
# ----------
# Training Loss: 0.0128, Accuracy: 100.00%
# Testing Accuracy: 68.00%
# Epoch 88/100
# ----------
# Training Loss: 0.0098, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 89/100
# ----------
# Training Loss: 0.0225, Accuracy: 99.43%
# Testing Accuracy: 56.00%
# Epoch 90/100
# ----------
# Training Loss: 0.0108, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Epoch 91/100
# ----------
# Training Loss: 0.0165, Accuracy: 100.00%
# Testing Accuracy: 68.00%
# Epoch 92/100
# ----------
# Training Loss: 0.0110, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 93/100
# ----------
# Training Loss: 0.0074, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 94/100
# ----------
# Training Loss: 0.0073, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 95/100
# ----------
# Training Loss: 0.0301, Accuracy: 99.43%
# Testing Accuracy: 52.00%
# Epoch 96/100
# ----------
# Training Loss: 0.0374, Accuracy: 99.43%
# Testing Accuracy: 60.00%
# Epoch 97/100
# ----------
# Training Loss: 0.0100, Accuracy: 100.00%
# Testing Accuracy: 64.00%
# Epoch 98/100
# ----------
# Training Loss: 0.0217, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 99/100
# ----------
# Training Loss: 0.0153, Accuracy: 100.00%
# Testing Accuracy: 60.00%
# Epoch 100/100
# ----------
# Training Loss: 0.0154, Accuracy: 100.00%
# Testing Accuracy: 56.00%
# Finished Training
